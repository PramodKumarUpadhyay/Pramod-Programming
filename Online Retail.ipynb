# %%
import pandas as pd
import numpy as np
import os as os
#import warnings
#import seaborn as sns
#import matplotlib.pyplot as plt

#warnings.filterwarnings("ignore")

# %%
# Industry way - Same step, slightly different

filepath = r"C:\Users\pramo\Desktop\Programming Learning\Python\Data"
filename = "Online Retail.xlsx"

data = pd.read_excel(os.path.join(filepath, filename))

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.head() # By default give 5 rows
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
data.tail() # By default gives last 5 rows
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France

# %%
data.shape # It Counts rows (starts from Zero) & Columns
# Out:
# (541909, 8)

# %%
print ("Number of Rows: ", data.shape[0])
print ("Numeber of columns: ", data.shape[1])
# Out:
# Number of Rows:  541909
# Numeber of columns:  8

# %%
data["Country"].nunique() # to Count how many number of country in data file
# Out:
# 38

# %%
print ("Number of Countires my products sold are: ", data["Country"].nunique())
# Out:
# Number of Countires my products sold are:  38

# %%
data.info() # shows data type of file
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
data["Quantity"].dtype
# Out:
# dtype('int64')

# %%
df = pd.DataFrame(data)
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
df.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
data.isnull()
# Out:
#         InvoiceNo  StockCode  Description  Quantity  InvoiceDate  UnitPrice  \
# 0           False      False        False     False        False      False
# 1           False      False        False     False        False      False
# 2           False      False        False     False        False      False
# 3           False      False        False     False        False      False
# 4           False      False        False     False        False      False
# ...           ...        ...          ...       ...          ...        ...
# 541904      False      False        False     False        False      False
# 541905      False      False        False     False        False      False
# 541906      False      False        False     False        False      False
# 541907      False      False        False     False        False      False
# 541908      False      False        False     False        False      False
#
#         CustomerID  Country
# ...

# %%
data.isnull().sum() # shows row number for missing value
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
pd.DataFrame(data.isnull().sum())
# Out:
#                   0
# InvoiceNo         0
# StockCode         0
# Description    1454
# Quantity          0
# InvoiceDate       0
# UnitPrice         0
# CustomerID   135080
# Country           0

# %%
pd.DataFrame(data.shape)
# Out:
#         0
# 0  541909
# 1       8

# %%
pd.DataFrame(data.head(3))
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
missing_df = pd.DataFrame(data.isnull().sum(), columns = ["MissingRows"] )

# %%
missing_df["Missing%"] = missing_df["MissingRows"]*100/len(data)

# %%
missing_df["Missing%"] = missing_df["Missing%"].round(2)

# %%
missing_df
# Out:
#              MissingRows  Missing%
# InvoiceNo              0      0.00
# StockCode              0      0.00
# Description         1454      0.27
# Quantity               0      0.00
# InvoiceDate            0      0.00
# UnitPrice              0      0.00
# CustomerID        135080     24.93
# Country                0      0.00

# %%
missing_df["Missing%"].sort_values()
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# Country         0.00
# Description     0.27
# CustomerID     24.93
# Name: Missing%, dtype: float64

# %%
missing_df = missing_df.sort_values("Missing%", ascending=True)
missing_df
# Out:
#              MissingRows  Missing%
# InvoiceNo              0      0.00
# StockCode              0      0.00
# Quantity               0      0.00
# InvoiceDate            0      0.00
# UnitPrice              0      0.00
# Country                0      0.00
# Description         1454      0.27
# CustomerID        135080     24.93

# %%
missing_df = missing_df.sort_values("Missing%", ascending=False)
missing_df
# Out:
#              MissingRows  Missing%
# CustomerID        135080     24.93
# Description         1454      0.27
# InvoiceNo              0      0.00
# StockCode              0      0.00
# Quantity               0      0.00
# InvoiceDate            0      0.00
# UnitPrice              0      0.00
# Country                0      0.00

# %%
missing_df.drop("CustomerID")
# Out:
#              MissingRows  Missing%
# Description         1454      0.27
# InvoiceNo              0      0.00
# StockCode              0      0.00
# Quantity               0      0.00
# InvoiceDate            0      0.00
# UnitPrice              0      0.00
# Country                0      0.00

# %%
data_2 = data.copy() # Copy of Original Data
data_2 = data_2.dropna(subset = ["CustomerID"]) # data_2.dropna() - it drops all columns
data_2.shape
# Out:
# (406829, 8)

# %%
data.drop_duplicates(subset ="StockCode", keep = False, inplace = True)

# %%
data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 1970      536545     21134                                  NaN         1
# 1985     C536548     20957         PORCELAIN HANGING BELL SMALL        -1
# 1987      536549    85226A                                  NaN         1
# 1988      536550     85044                                  NaN         1
# 2024      536552     20950                                  NaN         1
# ...          ...       ...                                  ...       ...
# 507867    579187     23609       SET 10 CARDS SNOWY ROBIN 17099         1
# 509369    579297    85179a              GREEN BITTY LIGHT CHAIN         1
# 512588    579512     23617  SET 10 CARDS SWIRLY XMAS TREE 17104         2
# 527065    580691    90214U            LETTER "U" BLING KEY RING        12
# 537224    581238    47591b             SCOTTIES CHILDRENS APRON         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
pd.DataFrame(data.shape)
# Out:
#      0
# 0  233
# 1    8
